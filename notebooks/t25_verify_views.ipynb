# %%
views_to_check = [
    "view_no2_classification_features",
    "view_balanced_pollution_samples", 
    "view_regional_daily_aggregates"
]

for view in views_to_check:
    try:
        df = client.get_view_data(database_id=DATABASE_ID, view_name=view)
        print(f"✓ {view}: {len(df)} rows returned")
    except Exception as e:
        print(f"✗ {view}: {e}")
